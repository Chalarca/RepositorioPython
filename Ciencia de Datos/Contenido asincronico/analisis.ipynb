# %% [markdown]
# # Importar paquetes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Leer datos

# %%
pd.set_option('display.max_columns', 35)

# %%
df = pd.read_excel("./Data/Data DS Cotton Plus.xlsx", sheet_name = "BD")
df.head()
# Out:
#    Cedula   Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0       1  Nombre Cliente 1  Aficionados           Si           No
# 1       2  Nombre Cliente 2  Esporádicos           Si           No
# 2       3  Nombre Cliente 3  Aficionados           Si           No
# 3       4  Nombre Cliente 4  Aficionados           Si           No
# 4       5  Nombre Cliente 5  Aficionados           Si           No
#
#    Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# 0                264800                       2                    0
# 1                179900                       1                    0
# 2                189800                       2                    0
# 3                 65900                       1                    0
# 4                238800                       2                    0
#
#    Nro Transacciones 2020  Tipo de Contacto Es Contactable  \
# 0                       0             11001             Si
# ...

# %% [markdown]
# # Analisis descriptivo

# %% [markdown]
# ## Tipo de datos y describe

# %%
df.shape
# Out:
# (9976, 40)

# %%
df.dtypes
# Out:
# Cedula                                                                int64
# Nombre Completo                                                      object
# Segmento                                                             object
# Compro 2019?                                                         object
# Compro 2020?                                                         object
# Monto Comprado 2019?                                                  int64
# Nro Transacciones 2019                                                int64
# Monto Comprado 2020                                                   int64
# Nro Transacciones 2020                                                int64
# Tipo de Contacto                                                      int64
# Es Contactable                                                       object
# Ciudad de Residencia                                                 object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9976 entries, 0 to 9975
# Data columns (total 40 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Cedula                                                            9976 non-null   int64
#  1   Nombre Completo                                                   9976 non-null   object
#  2   Segmento                                                          9976 non-null   object
#  3   Compro 2019?                                                      9976 non-null   object
#  4   Compro 2020?                                                      9976 non-null   object
#  5   Monto Comprado 2019?                                              9976 non-null   int64
#  6   Nro Transacciones 2019                                            9976 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                                                      count          mean  \
# Cedula                                              9976.0  4.988500e+03
# Monto Comprado 2019?                                9976.0  2.438670e+05
# Nro Transacciones 2019                              9976.0  2.462711e+00
# Monto Comprado 2020                                 9976.0  2.506701e+04
# Nro Transacciones 2020                              9976.0  2.635325e-01
# Tipo de Contacto                                    9976.0  9.268515e+03
# Mail                                                   0.0           NaN
# Direccion                                              0.0           NaN
# Fecha Nacimiento                                    9976.0  1.955487e+07
# Dia Nacimiento                                      9976.0  1.510876e+01
# Edad                                                9976.0  4.036187e+01
# Monto Total de ultima compra                        9976.0  5.902064e+05
# ...

# %%
df.drop(["Telefono Movil", "TelefonoOficina", "Telefono Casa", "Mail", "Direccion"], axis = 1, inplace = True)

# %%
df.describe().T
# Out:
#                                                      count          mean  \
# Cedula                                              9976.0  4.988500e+03
# Monto Comprado 2019?                                9976.0  2.438670e+05
# Nro Transacciones 2019                              9976.0  2.462711e+00
# Monto Comprado 2020                                 9976.0  2.506701e+04
# Nro Transacciones 2020                              9976.0  2.635325e-01
# Tipo de Contacto                                    9976.0  9.268515e+03
# Fecha Nacimiento                                    9976.0  1.955487e+07
# Dia Nacimiento                                      9976.0  1.510876e+01
# Edad                                                9976.0  4.036187e+01
# Monto Total de ultima compra                        9976.0  5.902064e+05
# Cantidad Articulos                                  9976.0  1.196933e+01
# Recencia (Tiempo transcurrido en semanas desde ...  9976.0  1.042382e+01
# ...

# %%
df.head()
# Out:
#    Cedula   Nombre Completo     Segmento Compro 2019? Compro 2020?  \
# 0       1  Nombre Cliente 1  Aficionados           Si           No
# 1       2  Nombre Cliente 2  Esporádicos           Si           No
# 2       3  Nombre Cliente 3  Aficionados           Si           No
# 3       4  Nombre Cliente 4  Aficionados           Si           No
# 4       5  Nombre Cliente 5  Aficionados           Si           No
#
#    Monto Comprado 2019?  Nro Transacciones 2019  Monto Comprado 2020  \
# 0                264800                       2                    0
# 1                179900                       1                    0
# 2                189800                       2                    0
# 3                 65900                       1                    0
# 4                238800                       2                    0
#
#    Nro Transacciones 2020  Tipo de Contacto Es Contactable  \
# 0                       0             11001             Si
# ...

# %% [markdown]
# ## Variables categoricas

# %% [markdown]
# Realizar graficos de barras

# %%
df["Segmento"].value_counts()
# Out:
# Aficionados    6845
# Esporádicos    2495
# Inactivo        296
# Adictos         181
# Curiosos        159
# Name: Segmento, dtype: int64

# %%
df["Ciudad de Residencia"].value_counts()
# Out:
# MEDELLIN               2075
# MANIZALES              1582
# BOGOTA                  697
# BARRANQUILLA            611
# PEREIRA                 591
#                        ...
# FLORIAN                   1
# URRAO                     1
# PURISIMA                  1
# CAJICA                    1
# CABRERA (SANTANDER)       1
# Name: Ciudad de Residencia, Length: 251, dtype: int64

# %%
df["Genero"].value_counts()
# Out:
# Mujer     5980
# Hombre    3996
# Name: Genero, dtype: int64

# %%
df["Estado Civil"].value_counts()
# Out:
# No hay informacion    9413
# Soltero                315
# Casado                 211
# Union Libre             23
# Divorciado              11
# Viudo                    3
# Name: Estado Civil, dtype: int64

# %%
df["Es Contactable"].value_counts()
# Out:
# Si    9976
# Name: Es Contactable, dtype: int64

# %%
#Medidas de tendencia central
#- media
#- mediana
#- moda

#Medidas de dispersion
#- correlaciones
#- desviacion estandar
#- varianzas
#- coeficiente de correlacion

# %%
sns.displot(df["Monto Comprado 2019?"])

# %%
sns.displot(df["Cantidad Articulos"])
