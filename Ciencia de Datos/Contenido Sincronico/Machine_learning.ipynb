# %%
import pandas as pd

Ejercicio = pd.read_csv("D:/Users/ACER/Desktop/Proteus + Ardudino/OFEI1204.txt", sep=":")
Ejercicio
# Out:
#                                 Ofertas Iniciales para   2017-12-04
# 0                                               AGENTE   AES CHIVOR
# 1    CHIVOR1 , D,  125,  125,  125,  125,  125,  12...          NaN
# 2    CHIVOR2 , D,  125,  125,  125,  125,  125,  12...          NaN
# 3    CHIVOR3 , D,  125,  125,  125,  125,  125,  12...          NaN
# 4    CHIVOR4 , D,  125,  125,  125,  125,  125,  12...          NaN
# ..                                                 ...          ...
# 512                                 FLORES1 , CONF,  1          NaN
# 513                                  FLORES1 , C,  GAS          NaN
# 514  FLORES4B , D,  450,  450,  450,  450,  450,  4...          NaN
# 515                                FLORES4B , CONF,  1          NaN
# 516                                 FLORES4B , C,  GAS          NaN
#
# [517 rows x 2 columns]

# %%
Ejercicio.rename(columns = {"Ofertas Iniciales para":"Valores", " 2017-12-04":"Agente"}, inplace=True)
Ejercicio
# Out:
#                                                Valores       Agente
# 0                                               AGENTE   AES CHIVOR
# 1    CHIVOR1 , D,  125,  125,  125,  125,  125,  12...          NaN
# 2    CHIVOR2 , D,  125,  125,  125,  125,  125,  12...          NaN
# 3    CHIVOR3 , D,  125,  125,  125,  125,  125,  12...          NaN
# 4    CHIVOR4 , D,  125,  125,  125,  125,  125,  12...          NaN
# ..                                                 ...          ...
# 512                                 FLORES1 , CONF,  1          NaN
# 513                                  FLORES1 , C,  GAS          NaN
# 514  FLORES4B , D,  450,  450,  450,  450,  450,  4...          NaN
# 515                                FLORES4B , CONF,  1          NaN
# 516                                 FLORES4B , C,  GAS          NaN
#
# [517 rows x 2 columns]

# %%
s=0
for i in Ejercicio["Agente"]:
    s=s+1
    if Ejercicio["Agente"][s] == "nan":
        print (Ejercicio["Agente"][s])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Python\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 517 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15604/1502826500.py in <module>
#       2 for i in Ejercicio["Agente"]:
#       3     s=s+1
# ----> 4     if Ejercicio["Agente"][s] == "nan":
#       5         print (Ejercicio["Agente"][s])
#       6
#
# D:\Python\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# ...
